# %%
# Import dependencies
import pandas as pd
import numpy as np

# %%
# Read in population csv
popn_df =pd.read_csv('resources/population.csv', skiprows=4)
popn_df.head()
# Out:
#                   Country Name Country Code     Indicator Name Indicator Code  \
# 0                        Aruba          ABW  Population, total    SP.POP.TOTL
# 1  Africa Eastern and Southern          AFE  Population, total    SP.POP.TOTL
# 2                  Afghanistan          AFG  Population, total    SP.POP.TOTL
# 3   Africa Western and Central          AFW  Population, total    SP.POP.TOTL
# 4                       Angola          AGO  Population, total    SP.POP.TOTL
#
#           1960         1961         1962         1963         1964  \
# 0      54608.0      55811.0      56682.0      57475.0      58178.0
# 1  130692579.0  134169237.0  137835590.0  141630546.0  145605995.0
# 2    8622466.0    8790140.0    8969047.0    9157465.0    9355514.0
# 3   97256290.0   99314028.0  101445032.0  103667517.0  105959979.0
# 4    5357195.0    5441333.0    5521400.0    5599827.0    5673199.0
#
#           1965  ...         2013         2014         2015         2016  \
# ...

# %%
# Read in gdp csv
gdp_df =pd.read_csv('resources/gdp.csv', skiprows=4)

# %%
# Read in electricity csv
elec_df =pd.read_csv('resources/MES_0123.csv', skiprows=8)

# %%
# Read in country lat and lon csv
country_df =pd.read_csv('resources/countries.csv')

# %%
continent_df = pd.read_csv('resources/continents2.csv')

# %%
main_df = pd.merge(main_df,df2[['alpha-2','alpha-3','name']],on='Key_Column', how='left')

# %%
continent_df
# Out:
#                   name alpha-2 alpha-3  country-code     iso_3166-2   region  \
# 0          Afghanistan      AF     AFG             4  ISO 3166-2:AF     Asia
# 1        Åland Islands      AX     ALA           248  ISO 3166-2:AX   Europe
# 2              Albania      AL     ALB             8  ISO 3166-2:AL   Europe
# 3              Algeria      DZ     DZA            12  ISO 3166-2:DZ   Africa
# 4       American Samoa      AS     ASM            16  ISO 3166-2:AS  Oceania
# ..                 ...     ...     ...           ...            ...      ...
# 244  Wallis and Futuna      WF     WLF           876  ISO 3166-2:WF  Oceania
# 245     Western Sahara      EH     ESH           732  ISO 3166-2:EH   Africa
# 246              Yemen      YE     YEM           887  ISO 3166-2:YE     Asia
# 247             Zambia      ZM     ZMB           894  ISO 3166-2:ZM   Africa
# 248           Zimbabwe      ZW     ZWE           716  ISO 3166-2:ZW   Africa
#
# ...

# %%
country_df
# Out:
#     country   latitude  longitude                  name
# 0        AD  42.546245   1.601554               Andorra
# 1        AE  23.424076  53.847818  United Arab Emirates
# 2        AF  33.939110  67.709953           Afghanistan
# 3        AG  17.060816 -61.796428   Antigua and Barbuda
# 4        AI  18.220554 -63.068615              Anguilla
# ..      ...        ...        ...                   ...
# 240      YE  15.552727  48.516388                 Yemen
# 241      YT -12.827500  45.166244               Mayotte
# 242      ZA -30.559482  22.937506          South Africa
# 243      ZM -13.133897  27.849332                Zambia
# 244      ZW -19.015438  29.154857              Zimbabwe
#
# [245 rows x 4 columns]

# %%
country_list = elec_df['Country'].unique()
print(len(country_list))
# Out:
# 53

# %%
country_list_df = pd.DataFrame(country_list,columns=['Country Name'])
country_list_df.head()
# Out:
#   Country Name
# 0    Australia
# 1      Austria
# 2      Belgium
# 3       Canada
# 4        Chile

# %%
main_df = pd.merge(country_list_df,popn_df,how='inner',on='Country Name')
main_df
# Out:
#        Country Name Country Code     Indicator Name Indicator Code  \
# 0         Australia          AUS  Population, total    SP.POP.TOTL
# 1           Austria          AUT  Population, total    SP.POP.TOTL
# 2           Belgium          BEL  Population, total    SP.POP.TOTL
# 3            Canada          CAN  Population, total    SP.POP.TOTL
# 4             Chile          CHL  Population, total    SP.POP.TOTL
# 5          Colombia          COL  Population, total    SP.POP.TOTL
# 6        Costa Rica          CRI  Population, total    SP.POP.TOTL
# 7           Denmark          DNK  Population, total    SP.POP.TOTL
# 8           Estonia          EST  Population, total    SP.POP.TOTL
# 9           Finland          FIN  Population, total    SP.POP.TOTL
# 10           France          FRA  Population, total    SP.POP.TOTL
# 11          Germany          DEU  Population, total    SP.POP.TOTL
# 12           Greece          GRC  Population, total    SP.POP.TOTL
# ...

# %%
main_df = pd.merge(main_df,gdp_df,how='inner',on='Country Name')
main_df
# Out:
#        Country Name Country Code_x   Indicator Name_x Indicator Code_x  \
# 0         Australia            AUS  Population, total      SP.POP.TOTL
# 1           Austria            AUT  Population, total      SP.POP.TOTL
# 2           Belgium            BEL  Population, total      SP.POP.TOTL
# 3            Canada            CAN  Population, total      SP.POP.TOTL
# 4             Chile            CHL  Population, total      SP.POP.TOTL
# 5          Colombia            COL  Population, total      SP.POP.TOTL
# 6        Costa Rica            CRI  Population, total      SP.POP.TOTL
# 7           Denmark            DNK  Population, total      SP.POP.TOTL
# 8           Estonia            EST  Population, total      SP.POP.TOTL
# 9           Finland            FIN  Population, total      SP.POP.TOTL
# 10           France            FRA  Population, total      SP.POP.TOTL
# 11          Germany            DEU  Population, total      SP.POP.TOTL
# ...

# %%
main_df.columns
# Out:
# Index(['Country Name', 'Country Code_x', 'Indicator Name_x',
#        'Indicator Code_x', '1960_x', '1961_x', '1962_x', '1963_x', '1964_x',
#        '1965_x',
#        ...
#        '2012_y', '2013_y', '2014_y', '2015_y', '2016_y', '2017_y', '2018_y',
#        '2019_y', '2020_y', '2021_y'],
#       dtype='object', length=132)

# %%
main_df_copy = main_df.melt(id_vars=['Country Name', 'Country Code_x', 'Indicator Name_x',
       'Indicator Code_x'], 
        var_name="Date", 
        value_name="Value")

main_df_copy['Date'] = main_df_copy['Date'].str.replace('_x', '')
main_df_copy['Date'] = main_df_copy['Date'].str.replace('_y', '')

# %%
main_df_copy['Country Name'].nunique()
# Out:
# 44

# %%
main_df_copy
# Out:
#          Country Name Country Code_x   Indicator Name_x Indicator Code_x  \
# 0           Australia            AUS  Population, total      SP.POP.TOTL
# 1             Austria            AUT  Population, total      SP.POP.TOTL
# 2             Belgium            BEL  Population, total      SP.POP.TOTL
# 3              Canada            CAN  Population, total      SP.POP.TOTL
# 4               Chile            CHL  Population, total      SP.POP.TOTL
# ...               ...            ...                ...              ...
# 5627            India            IND  Population, total      SP.POP.TOTL
# 5628            Malta            MLT  Population, total      SP.POP.TOTL
# 5629  North Macedonia            MKD  Population, total      SP.POP.TOTL
# 5630          Romania            ROU  Population, total      SP.POP.TOTL
# 5631           Serbia            SRB  Population, total      SP.POP.TOTL
#
#         Date        Value
# 0       1960  1.02765e+07
# 1       1960  7.04754e+06
# ...

# %%
# Save updated dataframe to csv
main_df_copy.to_csv("Resources/popn_gdp_v1.csv", index=False)
